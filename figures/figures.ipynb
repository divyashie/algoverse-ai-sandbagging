# %% [markdown]
# # Paper figures — generated from real `results/` JSONs
#
# All four figures load directly from `results/gauntlet/*.json` and `results/distributional/*.json` via `figure_utils.py`. No hardcoded values. COLM agent-behavior styling: colorblind-safe palette, no in-figure titles (LaTeX caption text printed under each figure). See `docs/figure_reconciliation.md` for provenance.

# %%
import sys; sys.path.insert(0, '.')
import figure_utils as F

# %% [markdown]
# ## Fig 1 — Cross-family detection matrix
# Activation probe (P2) is the only pillar that fires across all models.

# %%
F.fig_detection_matrix()
print('CAPTION:', F.CAPTIONS['matrix'])
# Out:
# CAPTION: Cross-family detection matrix: calibrated pillar scores for the trigger attack across eight models. The activation probe (P2) fires on all 8/8 models; the logit (P1) and behavioral (P3) pillars exceed the flag threshold on none. Activation is the only family-portable detector.

# %% [markdown]
# ## Fig 2 — Adversarial co-evolution arc
# Two minimal training edits drive the text-only audit AUC to chance while the attack stays functional.

# %%
F.fig_coevolution_arc()
print('CAPTION:', F.CAPTIONS['arc'])
# Out:
# CAPTION: Adversarial co-evolution of the text-only audit on the trigger attack. Two minimal training-data edits drive the joint AUC from 0.978 to chance (0.560, \textsc{indistinguishable}) while the trigger-conditional GSM8K suppression stays intact. v1 $n{=}60$; v2,v3 $n{=}200$; v3 trained at iter${=}200$ (iter${=}400$ collapsed to unconditional sandbagging).

# %% [markdown]
# ## Fig 3 — Sample efficiency of the distributional audit

# %%
F.fig_sample_efficiency()
print('CAPTION:', F.CAPTIONS['efficiency'])
# Out:
# CAPTION: Sample efficiency of the distributional audit (API-level, no weights). Mean $\pm$1 SD over 5 seeds; the audit saturates by $\approx$10 query pairs. (Measured on the v1 trigger substrate; cf.\ Fig.~arc for its erodability.)

# %% [markdown]
# ## Fig 4 — Cross-format fingerprinting

# %%
F.fig_crossformat()
print('CAPTION:', F.CAPTIONS['crossformat'])
# Out:
# CAPTION: Cross-format fingerprinting: distributional-audit AUC on the target (GSM8K) vs.\ adjacent (MMLU) format, within model, no reference. The format-selective xdomain attack shows a large gap ($\Delta{=}0.38$); the uniform trigger attack a small one ($\Delta{=}0.14$). The gap magnitude fingerprints the attack family.

# %% [markdown]
# ---
# *Run `python figures/figure_utils.py` to re-export PNGs.*
